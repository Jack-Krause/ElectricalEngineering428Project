# %%
import os, sys

from pathlib import Path

PROJECT_ROOT = Path("..").resolve()
sys.path.append(str(PROJECT_ROOT))

print("Project root: ", PROJECT_ROOT)

from src.train_yolo import train_baseline

train_baseline(epochs=3,
               imgsz=640,
               batch=8,
)
# Out:
# Project root:  /home/ubuntu/project/ElectricalEngineering428Project
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.5.1+cu121 CUDA:0 (NVIDIA A10G, 22588MiB)
# ...
